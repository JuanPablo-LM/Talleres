# %%
# !pip install xlrd openpyxl
import os
import pandas as pd
import numpy as np
import xlrd as xl
import openpyxl as op
import datetime
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **1er Punto**
# Buscar la base de países del World Economic Outlook (WEO) del FMI, subirla a su Drive y cargarla en el notebook conectándose a Google Drive.

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
base = pd.read_excel("weoapr2025all.xlsx", sheet_name="weoapr2025all")

# %% [markdown]
# ### Verificación

# %%
# Las primeras 5 filas
base.head()
# Out:
#   WEO Country Code  ISO WEO Subject Code      Country  \
# 0              512  AFG           NGDP_R  Afghanistan
# 1              512  AFG        NGDP_RPCH  Afghanistan
# 2              512  AFG             NGDP  Afghanistan
# 3              512  AFG            NGDPD  Afghanistan
# 4              512  AFG           PPPGDP  Afghanistan
#
#                         Subject Descriptor  \
# 0  Gross domestic product, constant prices
# 1  Gross domestic product, constant prices
# 2   Gross domestic product, current prices
# 3   Gross domestic product, current prices
# 4   Gross domestic product, current prices
#
#                                        Subject Notes  \
# 0  Expressed in billions of national currency uni...
# 1  Annual percentages of constant price GDP are y...
# 2  Expressed in billions of national currency uni...
# 3  Values are based upon GDP in national currency...
# 4  These data form the basis for the country weig...
#
# ...

# %%
# Las últimas 10 filas
base.tail(10)
# Out:
#                                        WEO Country Code  ISO WEO Subject Code  \
# 8616                                                698  ZWE     GGXONLB_NGDP
# 8617                                                698  ZWE           GGXWDN
# 8618                                                698  ZWE      GGXWDN_NGDP
# 8619                                                698  ZWE           GGXWDG
# 8620                                                698  ZWE      GGXWDG_NGDP
# 8621                                                698  ZWE          NGDP_FY
# 8622                                                698  ZWE              BCA
# 8623                                                698  ZWE        BCA_NGDPD
# 8624                                                NaN  NaN              NaN
# 8625  International Monetary Fund, World Economic Ou...  NaN              NaN
#
#        Country                                 Subject Descriptor  \
# ...

# %%
# 3 filas aleatorias
base.sample(3)
# Out:
#      WEO Country Code  ISO WEO Subject Code  Country  \
# 5682              142  NOR          NGDPRPC   Norway
# 6925              726  SOM          PCPIPCH  Somalia
# 7455              463  SYR         PCPIEPCH    Syria
#
#                                      Subject Descriptor  \
# 5682  Gross domestic product per capita, constant pr...
# 6925                 Inflation, average consumer prices
# 7455           Inflation, end of period consumer prices
#
#                                           Subject Notes              Units  \
# 5682  GDP is expressed in constant national currency...  National currency
# 6925  Annual percentages of average consumer prices ...     Percent change
# 7455  Annual percentages of end of period consumer p...     Percent change
#
#       Scale                      Country/Series-specific Notes         1980  \
# 5682  Units  See notes for:  Gross domestic product, consta...  529,775.630
# ...

# %%
# Pídale que muestre de la fila 2 a la 5 y solamente la segunda columna.
base.iloc[2:6, [1]]
# Out:
#    ISO
# 2  AFG
# 3  AFG
# 4  AFG
# 5  AFG

# %%
# Use len() para saber cuántas filas tiene
len(base)
# Out:
# 8626

# %%
# Use .shape para saber número de filas y columnas
base.shape
# Out:
# (8626, 61)

# %%
# Use .columns para ver el nombre de las columnas
base.columns
# Out:
# Index([             'WEO Country Code',                           'ISO',
#                     'WEO Subject Code',                       'Country',
#                   'Subject Descriptor',                 'Subject Notes',
#                                'Units',                         'Scale',
#        'Country/Series-specific Notes',                            1980,
#                                   1981,                            1982,
#                                   1983,                            1984,
#                                   1985,                            1986,
#                                   1987,                            1988,
#                                   1989,                            1990,
#                                   1991,                            1992,
#                                   1993,                            1994,
#                                   1995,                            1996,
# ...

# %%
# Use .dtypes para saber el tipo de dato de cada columna
base.dtypes
# Out:
# WEO Country Code          object
# ISO                       object
# WEO Subject Code          object
# Country                   object
# Subject Descriptor        object
#                           ...
# 2027                      object
# 2028                      object
# 2029                      object
# 2030                      object
# Estimates Start After    float64
# Length: 61, dtype: object

# %%
# Use .info() para ver toda la información del conjunto de datos (número de filas, columnas, nombre columnas, tipos de datos y si hay valores nulos)
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8626 entries, 0 to 8625
# Data columns (total 61 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   WEO Country Code               8625 non-null   object
#  1   ISO                            8624 non-null   object
#  2   WEO Subject Code               8624 non-null   object
#  3   Country                        8624 non-null   object
#  4   Subject Descriptor             8624 non-null   object
#  5   Subject Notes                  8624 non-null   object
#  6   Units                          8624 non-null   object
#  7   Scale                          8624 non-null   object
#  8   Country/Series-specific Notes  7648 non-null   object
#  9   1980                           3861 non-null   object
#  10  1981                           3995 non-null   object
#  11  1982                           4039 non-null   object
# ...

# %%
# !pip install wbdata
import wbdata

# %% [markdown]
# ### **2do Punto**
# Conectarse a la API del Banco Mundial y traer datos del PIB real para Estados Unidos, Alemania, Canadá, España, Francia e Italia, años 2010-2023.

# %%
pib = {"NY.GDP.PCAP.CD" : "pib real"}

fecha1 = datetime.datetime (2010,1,1)
fecha2 = datetime.datetime (2023,1,1)

base2 = wbdata.get_dataframe(pib , country=["USA", "CAN", "DEU", "ESP", "FRA", "ITA"], date=(fecha1, fecha2))

# %% [markdown]
# ### Verificación

# %%
# Las primeras 5 filas
base2.head()
# Out:
#                   pib real
# country date
# Canada  2023  54847.537011
#         2022  56496.927534
#         2021  52886.640781
#         2020  43537.898120
#         2019  46352.969521

# %%
# Las últimas 10 filas
base2.tail(10)
# Out:
#                         pib real
# country       date
# United States 2019  65227.956591
#               2018  62875.666138
#               2017  60047.719073
#               2016  57976.628204
#               2015  56849.469792
#               2014  55153.394018
#               2013  53297.386290
#               2012  51708.394061
#               2011  50024.881232
#               2010  48642.631209

# %%
# 3 filas aleatorias
base2.sample(3)
# Out:
#                   pib real
# country date
# Canada  2016  42314.103362
# Spain   2020  27233.942646
#         2014  29707.765509

# %%
# Pídale que muestre de la fila 2 a la 5 y solamente la segunda columna.
base2.iloc[2:6, [0]]
# Out:
#                   pib real
# country date
# Canada  2021  52886.640781
#         2020  43537.898120
#         2019  46352.969521
#         2018  46539.217790

# %%
# Use len() para saber cuántas filas tiene
len(base2)
# Out:
# 84

# %%
# Use .shape para saber número de filas y columnas
base2.shape
# Out:
# (84, 1)

# %%
# Use .columns para ver el nombre de las columnas
base2.columns
# Out:
# Index(['pib real'], dtype='object')

# %%
# Use .dtypes para saber el tipo de dato de cada columna
base2.dtypes
# Out:
# pib real    float64
# dtype: object

# %%
# Use .info() para ver toda la información del conjunto de datos (número de filas, columnas,
# nombre columnas, tipos de datos y si hay valores nulos)
base2.info()
# Out:
# <class 'wbdata.client.DataFrame'>
# MultiIndex: 84 entries, ('Canada', '2023') to ('United States', '2010')
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pib real  84 non-null     float64
# dtypes: float64(1)
# memory usage: 1.8+ KB

# %% [markdown]
# ### **3er Punto**
#
# Conectarse a la API del Banco Mundial y traer los siguientes datos para Brasil 2010-2023: crecimiento del PIB, PIB per cápita en PPA, tasa de inflación, tasa de desempleo y población.

# %%
indicadores = {"NY.GDP.MKTP.KD.ZG": "crecimiento pib",
               "NY.GDP.PCAP.PP.CD": "pib percapita en ppa",
               "FP.CPI.TOTL.ZG": "tasa de inflacion",
               "SL.UEM.TOTL.ZS": "tasa de desempleo",
               "SP.POP.TOTL": "poblacion"}

fecha3= datetime.datetime(2010,1,1)
fecha4= datetime.datetime(2023,1,1)

base3 = wbdata.get_dataframe(indicadores, country="BRA", date=(fecha3, fecha4))

# %% [markdown]
# ### Verificación

# %%
# Las primeras 5 filas
base3.head()
# Out:
#       crecimiento pib  pib percapita en ppa  tasa de inflacion  \
# date
# 2023         3.241655          21193.072142           4.593563
# 2022         3.016694          19873.703262           9.280106
# 2021         4.762604          18075.706005           8.301660
# 2020        -3.276759          16101.618306           3.211768
# 2019         1.220778          16069.838015           3.732976
#
#       tasa de desempleo    poblacion
# date
# 2023              7.947  211140729.0
# 2022              9.231  210306415.0
# 2021             13.158  209550294.0
# 2020             13.697  208660842.0
# 2019             11.936  207455459.0

# %%
# Las últimas 10 filas
base3.tail(10)
# Out:
#       crecimiento pib  pib percapita en ppa  tasa de inflacion  \
# date
# 2019         1.220778          16069.838015           3.732976
# 2018         1.783667          15463.742639           3.664850
# 2017         1.322869          14559.048890           3.446373
# 2016        -3.275917          14309.206149           8.739144
# 2015        -3.545763          14821.438317           9.029901
# 2014         0.503956          15827.308163           6.329040
# 2013         3.004823          15722.333524           6.204311
# 2012         1.921176          15198.086331           5.403499
# 2011         3.974423          15211.792039           6.636450
# 2010         7.528226          14451.715838           5.038727
#
#       tasa de desempleo    poblacion
# date
# 2019             11.936  207455459.0
# 2018             12.329  206107261.0
# 2017             12.792  204703445.0
# 2016             11.580  203218114.0
# 2015              8.538  201675532.0
# ...

# %%
# 3 filas aleatorias
base3.sample(3)
# Out:
#       crecimiento pib  pib percapita en ppa  tasa de inflacion  \
# date
# 2020        -3.276759          16101.618306           3.211768
# 2017         1.322869          14559.048890           3.446373
# 2021         4.762604          18075.706005           8.301660
#
#       tasa de desempleo    poblacion
# date
# 2020             13.697  208660842.0
# 2017             12.792  204703445.0
# 2021             13.158  209550294.0

# %%
# Pídale que muestre de la fila 2 a la 5 y solamente la segunda columna.
base3.iloc[2:6, [1]]
# Out:
#       pib percapita en ppa
# date
# 2021          18075.706005
# 2020          16101.618306
# 2019          16069.838015
# 2018          15463.742639

# %%
# Use len() para saber cuántas filas tiene
len(base3)
# Out:
# 14

# %%
# Use .shape para saber número de filas y columnas
base3.shape
# Out:
# (14, 5)

# %%
# Use .columns para ver el nombre de las columnas
base3.columns
# Out:
# Index(['crecimiento pib', 'pib percapita en ppa', 'tasa de inflacion',
#        'tasa de desempleo', 'poblacion'],
#       dtype='object')

# %%
# Use .dtypes para saber el tipo de dato de cada columna
base3.dtypes
# Out:
# crecimiento pib         float64
# pib percapita en ppa    float64
# tasa de inflacion       float64
# tasa de desempleo       float64
# poblacion               float64
# dtype: object

# %%
# Use .info() para ver toda la información del conjunto de datos (número de filas, columnas,
# nombre columnas, tipos de datos y si hay valores nulos)
base3.info()
# Out:
# <class 'wbdata.client.DataFrame'>
# Index: 14 entries, 2023 to 2010
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   crecimiento pib       14 non-null     float64
#  1   pib percapita en ppa  14 non-null     float64
#  2   tasa de inflacion     14 non-null     float64
#  3   tasa de desempleo     14 non-null     float64
#  4   poblacion             14 non-null     float64
# dtypes: float64(5)
# memory usage: 672.0+ bytes

# %% [markdown]
# ### **4to Punto**
# Traer dos conjuntos de datos de la página de datos abiertos del Gobierno de Colombia utilizando API. Los que le llamen la atención

# %%
import requests

# %%
# Primer conjunto de datos
url = "https://www.datos.gov.co/resource/qijw-htwa.json"
response = requests.get(url)
data = response.json()
base4 = pd.DataFrame(data)

# %%
# Segundo conjunto de datos
url = "https://www.datos.gov.co/resource/22f3-gynv.json"
response = requests.get(url)
data = response.json()
base5 = pd.DataFrame(data)

# %% [markdown]
# ### Verificación

# %%
from IPython.display import display

# Las primeras 5 filas
display(base4.head())

# Las últimas 10 filas
display(base4.tail(10))

# 3 filas aleatorias
display(base4.sample(3))

# Pídale que muestre de la fila 2 a la 5 y solamente la segunda columna
display(base4.iloc[2:6, [1]])

# Use len() para saber cuántas filas tiene
display(len(base4))

# Use .shape para saber número de filas y columnas
display(base4.shape)

# Use .columns para ver el nombre de las columnas
display(base4.columns)

# Use .dtypes para saber el tipo de dato de cada columna
display(base4.dtypes)

# Use .info() para ver toda la información del conjunto de datos
base4.info()
# Out:
#     a_o secretaria                              nombreestablecimiento    zona  \
# 0  2016     BOGOTA  GIMN NUEVO  SIDAUTO                           ...  URBANA
# 1  2016     BOGOTA  JARD INF LA CASITA DE CHENANO                 ...  URBANA
# 2  2016     BOGOTA                           ACADEMIA REAL PARA NIÑOS  URBANA
# 3  2016     BOGOTA  COL BILING RICHMOND                           ...  URBANA
# 4  2016     BOGOTA  COL COOP MONSEÑOR ISMAEL PERDOMO              ...  URBANA
#
#                  direccion                                           telefono  \
# 0            KR 90 A 91 96                                  4366460  /2521545
# 1  AV LAS AMERICAS 69 B 59                                            4177828
# 2      CL 42 A 87 I 10 SUR                                            4063716
# 3             KR 53 222 76  6763865 -- 6763864 -- 6763866 -- 6763836 -- 67...
# 4      DG 62 G SUR 72 A 41                      7764491 -- 7805045 -- 7784737
#
# ...

# %%
# Las primeras 5 filas
display(base5.head())

# Las últimas 10 filas
display(base5.tail(10))

# 3 filas aleatorias
display(base5.sample(3))

# Pídale que muestre de la fila 2 a la 5 y solamente la segunda columna
display(base5.iloc[2:6, [1]])

# Use len() para saber cuántas filas tiene
display(len(base5))

# Use .shape para saber número de filas y columnas
display(base5.shape)

# Use .columns para ver el nombre de las columnas
display(base5.columns)

# Use .dtypes para saber el tipo de dato de cada columna
display(base5.dtypes)

# Use .info() para ver toda la información del conjunto de datos
base5.info()
# Out:
#    anio numeromes nombremes       codigorubro  \
# 0  2019         1     Enero  1-0-00-1-01-1-01
# 1  2019         1     Enero  1-0-00-1-01-1-01
# 2  2019         1     Enero  1-0-00-1-01-1-01
# 3  2019         1     Enero  1-0-00-1-01-1-01
# 4  2019         1     Enero  1-0-00-1-01-1-04
#
#                                         nombrerubro niveluno  \
# 0         IMPUESTO SOBRE LA RENTA Y COMPLEMENTARIOS        1
# 1         IMPUESTO SOBRE LA RENTA Y COMPLEMENTARIOS        1
# 2         IMPUESTO SOBRE LA RENTA Y COMPLEMENTARIOS        1
# 3         IMPUESTO SOBRE LA RENTA Y COMPLEMENTARIOS        1
# 4  IMPUESTO PARA PRESERVAR LA SEGURIDAD DEMOCRÁTICA        1
#
#                      nombreniveluno niveldos  \
# 0  INGRESOS CORRIENTES DE LA NACIÓN        0
# 1  INGRESOS CORRIENTES DE LA NACIÓN        0
# 2  INGRESOS CORRIENTES DE LA NACIÓN        0
# 3  INGRESOS CORRIENTES DE LA NACIÓN        0
# 4  INGRESOS CORRIENTES DE LA NACIÓN        0
#
# ...

# %% [markdown]
# ### **5to Punto**
#  Investigue otra página de donde pueda traer datos económicos o sociales mediante API y
# cargue el conjunto de datos en el notebook.

# %%
# Install dependencies as needed:
# !pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
# Instalar kagglehub y las dependencias necesarias
# !pip install -q kagglehub[pandas-datasets]

# Importar librerías
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Nombre del archivo dentro del dataset
file_path = "btcusd_1-min_data.csv"

# Cargar el conjunto de datos desde Kaggle
base6 = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "mczielinski/bitcoin-historical-data",
    file_path
)

# Mostrar las primeras 5 filas
base6.head()
# Out:
# /tmp/ipykernel_2433/1546421636.py:12: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   base6 = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'bitcoin-historical-data' dataset.
#     Timestamp  Open  High   Low  Close  Volume
# 0  1325376060  4.58  4.58  4.58   4.58     0.0
# 1  1325376120  4.58  4.58  4.58   4.58     0.0
# 2  1325376180  4.58  4.58  4.58   4.58     0.0
# 3  1325376240  4.58  4.58  4.58   4.58     0.0
# 4  1325376300  4.58  4.58  4.58   4.58     0.0

# %% [markdown]
# ### Verificación

# %%
# Ver las primeras 5 filas
base6.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume
# 0  1325376060  4.58  4.58  4.58   4.58     0.0
# 1  1325376120  4.58  4.58  4.58   4.58     0.0
# 2  1325376180  4.58  4.58  4.58   4.58     0.0
# 3  1325376240  4.58  4.58  4.58   4.58     0.0
# 4  1325376300  4.58  4.58  4.58   4.58     0.0

# %%
# Ver las últimas 10 filas
base6.tail(10)
# Out:
#           Timestamp      Open      High       Low     Close    Volume
# 7707208  1787808540  78652.99  78652.99  78642.00  78647.11  0.052243
# 7707209  1787808600  78649.65  78663.49  78649.65  78663.49  0.747069
# 7707210  1787808660  78663.37  78663.37  78620.54  78629.16  1.236897
# 7707211  1787808720  78635.23  78635.23  78631.35  78635.22  0.137061
# 7707212  1787808780  78635.22  78635.22  78619.44  78625.64  0.349425
# 7707213  1787808840  78625.63  78626.59  78599.72  78617.34  2.080300
# 7707214  1787808900  78619.57  78619.57  78582.81  78598.75  2.465185
# 7707215  1787808960  78607.33  78625.58  78593.00  78625.58  3.162450
# 7707216  1787809020  78625.57  78656.20  78625.57  78652.90  0.412945
# 7707217  1787809080  78652.90  78690.58  78652.90  78690.58  0.192006

# %%
# Ver 3 filas aleatorias
base6.sample(3)
# Out:
#           Timestamp      Open      High       Low     Close    Volume
# 3632866  1543348020   3714.81   3719.09   3711.99   3712.38  5.299990
# 2140972  1453834380    393.46    393.46    392.44    392.44  1.449682
# 5003552  1625589180  33881.07  33912.98  33881.07  33906.86  1.038047

# %%
# Pídale que muestre de la fila 2 a la 5 y solamente la segunda columna
base6.iloc[2:6, [1]]
# Out:
#    Open
# 2  4.58
# 3  4.58
# 4  4.58
# 5  4.58

# %%
# Número de filas
len(base6)
# Out:
# 7707218

# %%
# Número de filas y columnas
base6.shape
# Out:
# (7707218, 6)

# %%
# Nombre de las columnas
base6.columns
# Out:
# Index(['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
# Tipo de datos
base6.dtypes
# Out:
# Timestamp      int64
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume       float64
# dtype: object

# %%
 # Información general
base6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7707218 entries, 0 to 7707217
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Timestamp  int64
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Volume     float64
# dtypes: float64(5), int64(1)
# memory usage: 352.8 MB
